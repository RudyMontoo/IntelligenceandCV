# %%
import cv2

# %%
haar_features=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
import cv2
haar_features = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
cap=cv2.VideoCapture(1)
while True:
    flag, frame = cap.read()
    if not flag:
        print("camera not working")
        break
    faces = haar_features.detectMultiScale(frame, scaleFactor=1.3)
    for x, y, w, h in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
    cv2.imshow('frame', frame)
    if cv2.waitKey(1) == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# [ WARN:0@1474.223] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video1): can't open camera by index
# ioctl(VIDIOC_QBUF): Bad file descriptor

# %%
URL ="https://www.youtube.com/watch?v=KnviRvdmFTc"

#format : best[ext=mp4]

ydl_options = {
    'format': 'best[ext=mp4]',
    }

with yt_dlp.YoutubeDL(ydl_options) as ydl:
    info = ydl.extract_info(URL, download=False)
    video_url = info['url']
    cap = cv2.VideoCapture(video_url)
    i=0
    while True:
        flag, frame = cap.read()
        if not flag:
            print("camera not accessible")
            break
        cv2.imshow("Camera", frame)
        i+=1
        # cv2.imwrite(f"capture_image/img_{i}.jpg", frame)
        key=cv2.waitKey(25) & 0xFF

        if key==27: #ESC
            break
    cap.release()
    cv2.destroyAllWindows()
